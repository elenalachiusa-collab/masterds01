# %%
def greet (name):
    name = name.upper()
    print(f"Hello  {name}")

# %%
greet ("Alice")
# Out:
# Hello  ALICE

# %%
employee = "Salim"
greet (employee)
# Out:
# Hello  SALIM

# %%
employee
# Out:
# 'Salim'

# %%
# !pip install numpy == 2.3 #per importare una libreria
# Out:
# ERROR: Invalid requirement: '==': Expected package name at the start of dependency specifier
#     ==
#     ^

# %%
import numpy

# %%
dir(numpy) #per vedere le funzioni all'interno di una libreria
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__array_namespace_info__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_array_api_info',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
# ...

# %%
numpy.arange (start=100, stop= 200, step= 33)
# Out:
# array([100, 133, 166, 199])

# %%
from numpy import arange

# %%
arange (start=100, stop= 200, step= 33)
# Out:
# array([100, 133, 166, 199])

# %% [markdown]
# #REQUESTS library

# %%
# !pip install requests

# %%
url = #mettere the urlstring variable (link scaricato)
import requests

response= requests.get(url)
response.text
# Out:
#   Cell In[35], line 1
#     url = #mettere the urlstring variable (link scaricato)
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# #CSV LIBRARY

# %%
import csv
#per importare un file 
with open("my_data1.csv") as f:
    reader = csv.DictReader(f)
    for row in reader:
        print (row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[46], line 3
#       1 import csv
#       2 #per importare un file
# ----> 3 with open("my_data1.csv") as f:
#       4     reader = csv.DictReader(f)
#       5     for row in reader:
#
# File ~\anaconda3\envs\myenv311\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'my_data1.csv'
