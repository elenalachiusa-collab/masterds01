# %%
print "Caio123"
# Out:
#   Cell In[1], line 1
#     print "Caio123"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print "Ciao"
# Out:
#   Cell In[2], line 1
#     print "Ciao"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print ("Ciao")
# Out:
# Ciao
