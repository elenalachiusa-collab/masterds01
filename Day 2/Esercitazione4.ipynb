# %%
range(20
# Out:
#   Cell In[5], line 1
#     range(20:2)
#             ^
# SyntaxError: invalid syntax

# %%
for i in range (2,20,2):
    print (i)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
for i in range(3):
    #inner loop fpr the rows
    for j in range(5): #loop for  coulums
            print("*", end = "")
    
    print()
# Out:
# *****
# *****
# *****

# %%
counter = 1
while counter = 0:
    print (counter/2)
    if counter < 1:
        break
# Out:
#   Cell In[5], line 2
#     while counter = 0:
#           ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
