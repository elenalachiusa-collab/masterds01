# %%
s1 = 'good place'
s1
# Out:
# 'good place'

# %%
s2= "bad day"
s2
# Out:
# 'bad day'

# %%
s3 = 'Yesterday mornign you say: "Hello!"'
s3
# Out:
# 'Yesterday mornign you say: "Hello!"'

# %%
place = "Napoli"
print(f'Good {place}')
# Out:
# Good Napoli

# %%
plate = "pasta con il sugo"
plate[1:-2]
# Out:
# 'asta con il su'

# %%
plate[:2].lower() + plate[2:-2] + plate[-2:].upper()
# Out:
# 'pasta con il suGO'
