# %%
a=3
b=2

# %%
a
# Out:
# 3

# %%
b
# Out:
# 2

# %%
risultato_1= a+b
print(risultato_1)
# Out:
# 5

# %%
risultato_1= a-b
print(risultato_1)
# Out:
# 1

# %%
risultato_1= a*b
print(risultato_1)
# Out:
# 6

# %%
a=3

# %%
a ==3
# Out:
# True

# %%
a= 7

# %%
b= 3

# %%
resullt= a += b
print(resullt)
# Out:
#   Cell In[14], line 1
#     resullt= a += b
#                ^
# SyntaxError: invalid syntax

# %%
a += b
a
# Out:
# 16

# %%
a = 7
b = 3
a += b
a
# Out:
# 10
