# %%
b= "maxdistance"

# %%
maxdistanca = 25
Temperature = 12.5 
isRaing= True
greet_ing = "Julie"

# %%
type(maxdistanca)
# Out:
# int

# %%
type(Temperature)
# Out:
# float

# %%
type(isRaing)
# Out:
# bool

# %%
type(greet_ing)
# Out:
# str

# %%
a= 45

# %%
float(a)
# Out:
# 45.0

# %%
b= 3.14159

# %%
int(b)
# Out:
# 3

# %%
x=str(c)

# %%
x
# Out:
# '99.99'

# %%
y= float(x)

# %%
y
# Out:
# 99.99
