# %%
if 10>5:
    print("Ten is bigger than five")
else:
    print( "It's lower")

print("Today is sunny")
# Out:
# Ten is bigger than five
# Today is sunny

# %%
def sum(a,b):
    """
    This function re
    """
    result = a+b #a is added to b and associated with "result"
    return result #we return the "result" variable

# %%
sum(10,20)
# Out:
# 30

# %%
sum("Mike","Elisa")
# Out:
# 'MikeElisa'

# %%
sum("Mike", 50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sum("Mike", 50)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
age = 30

# %%
Age = 20

# %%
age
# Out:
# 30

# %%
Age
# Out:
# 20

# %%
building1 = "church"

# %%
building1_name = "church" #snake syntax
building1Name = "church" #cameL ì syntax

building1_height = 100

building2_name = "Stadium"
building2_height = 100

building3_name = "Igloo"
building3_height = 100

# %%
print(building4_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(building4_name)
#
# NameError: name 'building4_name' is not defined

# %%
age = 40.5

# %%
student name = "Maria"
# Out:
#   Cell In[15], line 1
#     student name = "Maria"
#             ^
# SyntaxError: invalid syntax

# %%
student_name = "Maria"
print(student_name)
print(student_name+student_name)
# Out:
# Maria
# MariaMaria

# %%
type (age)
# Out:
# float

# %%
dangerous = True
type (dangerous)
# Out:
# bool

# %%
type(3>5)
# Out:
# bool

# %%
d = str(dangerous)

# %%
tyoe(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 tyoe(d)
#
# NameError: name 'tyoe' is not defined

# %%
type (d)
# Out:
# str

# %%
d
# Out:
# 'True'

# %%
s = "20"

# %%
s+s
# Out:
# '2020'

# %%
int(s)+int(s)
# Out:
# 40

# %%
a= 20
b = "Julie"
c= True
d= 3.5

# %%
type (d)
# Out:
# float

# %%
flot(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 flot(a)
#
# NameError: name 'flot' is not defined

# %%
float(a)
# Out:
# 20.0

# %%
type(float(a))
# Out:
# float

# %%
10%3
# Out:
# 1

# %%
def is_even(a):
    """
    this function returns True if the number is even,
    otherwise it returns False
    """
    result = a %2
    if result ==1:
        return False
    else:
        return True
is_even(11)
# Out:
# False

# %%
def is_even(a):
    """
    this function returns True if the number is even,
    otherwise it returns False
    """
    if a%2 ==1:
        return False
    else:
        return True
is_even(11)
# Out:
# False

# %%
def is_even_3(a):
    """
    this function returns True if the number is even,
    otherwise it returns False
    """
    if a%2 ==1:
        return False
    else:
        return True
print(is_even_3(10))
print(is_even_3(11))
# Out:
# True
# False

# %%
def is_even_3(a):
    """
    this function returns True if the number is even,
    otherwise it returns False
    """
    if a%2 ==1:
        return True
    
    return False
print(is_even_3(10))
print(is_even_3(11))
# Out:
# False
# True

# %%
def is_even_4(a):
    """
    this function returns True if the number is even,
    otherwise it returns False
    """
    return (a % 2 == 0) 

print(is_even_4(10))
print(is_even_4(11))
# Out:
# True
# False

# %%
2 ** 10
# Out:
# 1024

# %%
2 ** (-3.5)
# Out:
# 0.08838834764831845

# %%
11/3 #the value of the ratio
# Out:
# 3.6666666666666665

# %%
11//3 #integer part of the division
# Out:
# 3

# %%
int(11/3)
# Out:
# 3

# %%
a = 10
b = 5

a += b #we want to add a to b, so equivalent to "a= a+b"
a
# Out:
# 15

# %%
a == b
# Out:
# False

# %%
a != b #to say they are different
# Out:
# True

# %%
a= 10
b= 5
c= 0
d= -10

# %%
a,b,c,d
# Out:
# (10, 5, 0, -10)

# %%
a > b and c > d
# Out:
# True

# %%
a < b and c > d or a < b and c > d #se ho un "and" ho true solo se entrmabi sono veri altrimenti ho false 
False and True or False

# %%
s = "I have to fix mu sink" #in this case it is indifferent 
s
# Out:
# 'I have to fix mu sink'

# %%
s= 'my wife told me: "you have to fix our sink!"'
s
# Out:
# 'my wife told me: "you have to fix our sink!"'

# %%
s2 = "these are the results:
- MIke: 3
- Elisa : 10
"
# Out:
#   Cell In[68], line 1
#     s2 = "these are the results:
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s2 = """these are the results:
- MIke: 3
- Elisa : 10
"""

# %%
s3 = "Today is a good day"
s3
# Out:
# 'Today is a good day'

# %%
s3[:10] #first ten characters
# Out:
# 'Today is a'

# %%
s3[-10:] #last ten characters
# Out:
# ' good day'

# %%
s3[4:6] # è escluso il 6, infatti ho solo il 4 carattere e il quinto che è lo spazio
# Out:
# 'y '

# %%
s3[2:6:2] #parte dalla seconda, il conto è da 0, arriva a 6th escluso e fa salti di 2
# Out:
# 'dy'

# %%
s3.upper() #mostra la stringa tutta maiuscola
# Out:
# 'TODAY IS A GOOD DAY'

# %%
s3.find)"GOOD")
# Out:
#   Cell In[78], line 1
#     s3.find)"GOOD")
#            ^
# SyntaxError: unmatched ')'

# %%
s3.find ("good") #il posto che occupa questa parola ma sempre partendo da 0
# Out:
# 11

# %%
s3.replace("good", "bad".upper())
# Out:
# 'Today is a BAD day'

# %%
name = "Angela"
print("Hello " + name)
print("Hello {name}!")
print(f"Hello {name}!")
print(f"Hello\n{name}!")
# Out:
# Hello Angela
# Hello {name}!
# Hello Angela!
# Hello
# Angela!

# %%
print("Hello, %s" % "Angela")
# Out:
# Hello, Angela
